# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('C:\\Users\\divya\\OneDrive\\Desktop\\HealthCareApp\\HealthCareApp\\Data\\kidney.csv')
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# std     79.281714   50.503006    5.741126   10.408752    3.193904    2.912587
# min     22.000000    1.500000    0.400000    4.500000    2.500000    3.100000
# 25%     99.000000   27.000000    0.900000  135.000000    3.800000   10.300000
# 50%    121.000000   42.000000    1.300000  138.000000    4.400000   12.650000
# 75%    163.000000   66.000000    2.800000  142.000000    4.900000   15.000000
# max    490.000000  391.000000   76.000000  163.000000   47.000000   17.800000

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df.columns[df.dtypes=='object']
# Out:
# Index(['rbc', 'pc', 'pcc', 'ba', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['classification'] = df['classification'].replace(to_replace={'ckd':1.0,'ckd\t':1.0,'notckd':0.0,'no':0.0})

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0
# ..             ...
# 395            0.0
# 396            0.0
# 397            0.0
# 398            0.0
# 399            0.0
#
# [400 rows x 26 columns]

# %%
df['classification'].value_counts()
# Out:
# 1.0    250
# 0.0    150
# Name: classification, dtype: int64

# %%
df['classification'] = df['classification'].replace(to_replace={1:"Chronic",0:"Non-Chronic"})

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0          Chronic
# 1          Chronic
# 2          Chronic
# 3          Chronic
# 4          Chronic
# ..             ...
# 395    Non-Chronic
# 396    Non-Chronic
# 397    Non-Chronic
# 398    Non-Chronic
# 399    Non-Chronic
#
# [400 rows x 26 columns]

# %%
df.rename(columns={'classification':'class'},inplace=True)

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#            class
# 0        Chronic
# 1        Chronic
# 2        Chronic
# 3        Chronic
# 4        Chronic
# ..           ...
# 395  Non-Chronic
# 396  Non-Chronic
# 397  Non-Chronic
# 398  Non-Chronic
# 399  Non-Chronic
#
# [400 rows x 26 columns]

# %%
df['cad'] = df['cad'].replace(to_replace='\tno',value=0)
df['dm'] = df['dm'].replace(to_replace={'\tno':"no",'\tyes':"yes",' yes':"yes", '':np.nan})

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#            class
# 0        Chronic
# 1        Chronic
# 2        Chronic
# 3        Chronic
# 4        Chronic
# ..           ...
# 395  Non-Chronic
# 396  Non-Chronic
# 397  Non-Chronic
# 398  Non-Chronic
# 399  Non-Chronic
#
# [400 rows x 26 columns]

# %%
df['cad'].value_counts()
df.isnull().sum()
# Out:
# id         0
# age        9
# bp        12
# sg        47
# al        46
# su        49
# rbc      152
# pc        65
# pcc        4
# ba         4
# bgr       44
# bu        19
# sc        17
# sod       87
# pot       88
# hemo      52
# pcv       70
# wc       105
# rc       130
# htn        2
# dm         2
# cad        2
# appet      1
# pe         1
# ane        1
# class      0
# dtype: int64

# %%
df=df.drop(["su","rbc","rc","wc","pot","sod"],axis=1)

# %%
df
# Out:
#       id   age    bp     sg   al        pc         pcc          ba    bgr  \
# 0      0  48.0  80.0  1.020  1.0    normal  notpresent  notpresent  121.0
# 1      1   7.0  50.0  1.020  4.0    normal  notpresent  notpresent    NaN
# 2      2  62.0  80.0  1.010  2.0    normal  notpresent  notpresent  423.0
# 3      3  48.0  70.0  1.005  4.0  abnormal     present  notpresent  117.0
# 4      4  51.0  80.0  1.010  2.0    normal  notpresent  notpresent  106.0
# ..   ...   ...   ...    ...  ...       ...         ...         ...    ...
# 395  395  55.0  80.0  1.020  0.0    normal  notpresent  notpresent  140.0
# 396  396  42.0  70.0  1.025  0.0    normal  notpresent  notpresent   75.0
# 397  397  12.0  80.0  1.020  0.0    normal  notpresent  notpresent  100.0
# 398  398  17.0  60.0  1.025  0.0    normal  notpresent  notpresent  114.0
# 399  399  58.0  80.0  1.025  0.0    normal  notpresent  notpresent  131.0
#
#        bu   sc  hemo pcv  htn   dm cad appet   pe  ane        class
# 0    36.0  1.2  15.4  44  yes  yes  no  good   no   no      Chronic
# 1    18.0  0.8  11.3  38   no   no  no  good   no   no      Chronic
# 2    53.0  1.8   9.6  31   no  yes  no  poor   no  yes      Chronic
# 3    56.0  3.8  11.2  32  yes   no  no  poor  yes  yes      Chronic
# 4    26.0  1.4  11.6  35   no   no  no  good   no   no      Chronic
# ..    ...  ...   ...  ..  ...  ...  ..   ...  ...  ...          ...
# 395  49.0  0.5  15.7  47   no   no  no  good   no   no  Non-Chronic
# 396  31.0  1.2  16.5  54   no   no  no  good   no   no  Non-Chronic
# 397  26.0  0.6  15.8  49   no   no  no  good   no   no  Non-Chronic
# 398  50.0  1.0  14.2  51   no   no  no  good   no   no  Non-Chronic
# 399  18.0  1.1  15.8  53   no   no  no  good   no   no  Non-Chronic
#
# [400 rows x 20 columns]

# %%
df["pcv"]=df["pcv"].fillna(method="ffill")
df.drop(["pc"],axis=1,inplace=True)
df["hemo"]=df["hemo"].fillna(method="ffill")
df.drop(["sg"],axis=1,inplace=True)
df=df.fillna(method="ffill")
df.drop(["ba"],axis=1,inplace=True)
df.drop(["pe"],axis=1,inplace=True)
df.drop(["cad"],axis=1,inplace=True)
df.drop(["ane"],axis=1,inplace=True)

# %%
df
# Out:
#       id   age    bp   al         pcc    bgr    bu   sc  hemo pcv  htn   dm  \
# 0      0  48.0  80.0  1.0  notpresent  121.0  36.0  1.2  15.4  44  yes  yes
# 1      1   7.0  50.0  4.0  notpresent  121.0  18.0  0.8  11.3  38   no   no
# 2      2  62.0  80.0  2.0  notpresent  423.0  53.0  1.8   9.6  31   no  yes
# 3      3  48.0  70.0  4.0     present  117.0  56.0  3.8  11.2  32  yes   no
# 4      4  51.0  80.0  2.0  notpresent  106.0  26.0  1.4  11.6  35   no   no
# ..   ...   ...   ...  ...         ...    ...   ...  ...   ...  ..  ...  ...
# 395  395  55.0  80.0  0.0  notpresent  140.0  49.0  0.5  15.7  47   no   no
# 396  396  42.0  70.0  0.0  notpresent   75.0  31.0  1.2  16.5  54   no   no
# 397  397  12.0  80.0  0.0  notpresent  100.0  26.0  0.6  15.8  49   no   no
# 398  398  17.0  60.0  0.0  notpresent  114.0  50.0  1.0  14.2  51   no   no
# 399  399  58.0  80.0  0.0  notpresent  131.0  18.0  1.1  15.8  53   no   no
#
#     appet        class
# 0    good      Chronic
# 1    good      Chronic
# 2    poor      Chronic
# 3    poor      Chronic
# 4    good      Chronic
# ..    ...          ...
# 395  good  Non-Chronic
# 396  good  Non-Chronic
# 397  good  Non-Chronic
# 398  good  Non-Chronic
# 399  good  Non-Chronic
#
# [400 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# id       0
# age      0
# bp       0
# al       0
# pcc      0
# bgr      0
# bu       0
# sc       0
# hemo     0
# pcv      0
# htn      0
# dm       0
# appet    0
# class    0
# dtype: int64

# %%
df=df.replace("\t?",31)

# %%
df
# Out:
#       id   age    bp   al         pcc    bgr    bu   sc  hemo pcv  htn   dm  \
# 0      0  48.0  80.0  1.0  notpresent  121.0  36.0  1.2  15.4  44  yes  yes
# 1      1   7.0  50.0  4.0  notpresent  121.0  18.0  0.8  11.3  38   no   no
# 2      2  62.0  80.0  2.0  notpresent  423.0  53.0  1.8   9.6  31   no  yes
# 3      3  48.0  70.0  4.0     present  117.0  56.0  3.8  11.2  32  yes   no
# 4      4  51.0  80.0  2.0  notpresent  106.0  26.0  1.4  11.6  35   no   no
# ..   ...   ...   ...  ...         ...    ...   ...  ...   ...  ..  ...  ...
# 395  395  55.0  80.0  0.0  notpresent  140.0  49.0  0.5  15.7  47   no   no
# 396  396  42.0  70.0  0.0  notpresent   75.0  31.0  1.2  16.5  54   no   no
# 397  397  12.0  80.0  0.0  notpresent  100.0  26.0  0.6  15.8  49   no   no
# 398  398  17.0  60.0  0.0  notpresent  114.0  50.0  1.0  14.2  51   no   no
# 399  399  58.0  80.0  0.0  notpresent  131.0  18.0  1.1  15.8  53   no   no
#
#     appet        class
# 0    good      Chronic
# 1    good      Chronic
# 2    poor      Chronic
# 3    poor      Chronic
# 4    good      Chronic
# ..    ...          ...
# 395  good  Non-Chronic
# 396  good  Non-Chronic
# 397  good  Non-Chronic
# 398  good  Non-Chronic
# 399  good  Non-Chronic
#
# [400 rows x 14 columns]

# %%
print(df.columns)
print(df.shape[1])
# Out:
# Index(['id', 'age', 'bp', 'al', 'pcc', 'bgr', 'bu', 'sc', 'hemo', 'pcv', 'htn',
#        'dm', 'appet', 'class'],
#       dtype='object')
# 14

# %%
df.head()
# Out:
#    id   age    bp   al         pcc    bgr    bu   sc  hemo pcv  htn   dm  \
# 0   0  48.0  80.0  1.0  notpresent  121.0  36.0  1.2  15.4  44  yes  yes
# 1   1   7.0  50.0  4.0  notpresent  121.0  18.0  0.8  11.3  38   no   no
# 2   2  62.0  80.0  2.0  notpresent  423.0  53.0  1.8   9.6  31   no  yes
# 3   3  48.0  70.0  4.0     present  117.0  56.0  3.8  11.2  32  yes   no
# 4   4  51.0  80.0  2.0  notpresent  106.0  26.0  1.4  11.6  35   no   no
#
#   appet    class
# 0  good  Chronic
# 1  good  Chronic
# 2  poor  Chronic
# 3  poor  Chronic
# 4  good  Chronic

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['bgr'],color='blue')
plt.title("bgr Distribution",fontsize=16)
plt.show()
# Out:
# c:\Users\divya\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['bgr'],color='blue')
plt.title("bgr Distribution",fontsize=16)
plt.show()
# Out:
# c:\Users\divya\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['hemo'],color='blue')
plt.title("hemo Distribution",fontsize=16)
plt.show()
# Out:
# c:\Users\divya\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['sc'],color='blue')
plt.title("sc Distribution",fontsize=16)
plt.show()
# Out:
# c:\Users\divya\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df, hue='class')

# %%
df.to_csv('C:\\Users\\divya\\OneDrive\\Desktop\\HealthCareApp\\HealthCareApp\\Data\\filter-kidney.csv')
